# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
from bs4 import BeautifulSoup


options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
# options.add_argument('--headless')
driver = webdriver.Chrome("/home/sandeepa/Downloads/chromedriver", options=options)

# %%
def fetchData(query):
    driver.get("https://www.flipkart.com/")
    button=driver.find_element_by_class_name("_3Njdz7")
    if button.is_displayed():
        driver.execute_script("arguments[0].click();", button)
    
    elem = driver.find_element_by_name("q")
    elem.clear()
    elem.send_keys(query)
    elem.send_keys(Keys.RETURN)

# %%
def clickButton(prodURL):
    driver.get(prodURL)
    try:
        button=driver.find_element_by_class_name("_2lY4Z6")
        if button.is_displayed():
            driver.execute_script("arguments[0].click();", button)
            time.sleep(1)
        return driver.page_source
    except:
        return driver.page_source

def getOffers(prodURL):
    prodPage=clickButton(prodURL)
    prodSoup=BeautifulSoup(prodPage,'html.parser')
    offers=prodSoup.find_all('span',class_="_7g_MLT row")
    return offers

# %%
def get_products(soup):
    products=soup.find_all('div',class_="_3liAhj")
    i=1
    for product in products:

        title=product.find('a',class_="_2cLu-l")
        print(title.text)
        link='https://www.flipkart.com'+title.get('href')

        price=product.find('div',class_="_1vC4OE")
        print(price.text)

        ratings=product.find('div',class_="hGSR34")
        if(ratings==None):
            print('"No ratings for the product"')
        else:
            print(ratings.text)

        offers=getOffers(link)
        for offer in offers:
            off=offer.find('li',class_="_2-n-Lg col")
            print(off.text)
        print('-'*100)
        if(i==1):
            break
        i=i+1

# %%
def get_next_page(soup):
    next_page=soup.findAll('a',class_="_3fVaIS")
    next_page_link='https://www.flipkart.com'+(next_page[len(next_page)-1].get('href'))
    return next_page_link

# %%
query='realme'
fetchData(query)

count=0
url=driver.current_url
main_url=url
while True:
    if count!=0:
        page=requests.get(main_url)    
        soup = BeautifulSoup(page.text, 'html.parser')
        new_url=get_next_page(soup)
        url=new_url
        main_url=new_url
    
    print(url)
    page=requests.get(url)      
    soup = BeautifulSoup(page.text, 'html.parser')
    get_products(soup)
        
    if(count==12):
        break
    count=count+1
# Out:
# https://www.flipkart.com/search?q=realme&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# Realme X2 (Pearl Blue, 128 GB)
# ₹18,999
# 4.6
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹1000 discount(price inclusive of discount)T&C
# No cost EMI ₹1,584/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Realme X2 (Pearl White, 128 GB)
# ₹19,999
# 4.6
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹1000 discount(price inclusive of discount)T&C
# No cost EMI ₹1,667/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Realme X2 (Pearl Blue, 128 GB)
# ₹19,999
# 4.6
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹1000 discount(price inclusive of discount)T&C
# No cost EMI ₹1,667/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Realme X2 (Pearl White, 128 GB)
# ₹18,999
# 4.6
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹1000 discount(price inclusive of discount)T&C
# No cost EMI ₹1,584/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# https://www.flipkart.com/search?q=realme&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2
# Realme 3 Pro (Lightning Purple, 64 GB)
# ₹11,999
# 4.5
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹6000 discount(price inclusive of discount)T&C
# No cost EMI ₹1,000/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Realme X2 Pro (Neptune Blue, 128 GB)
# ₹29,999
# 4.6
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹2000 discount(price inclusive of discount)T&C
# No cost EMI ₹2,500/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Realme X2 Pro (Neptune Blue, 256 GB)
# ₹33,999
# 4.6
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹2000 discount(price inclusive of discount)T&C
# No cost EMI ₹2,834/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Realme X2 Pro (Lunar White, 256 GB)
# ₹33,999
# 4.6
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Get upto ₹11850 off on exchangeBuy with Exchange
# Special PriceExtra ₹2000 discount(price inclusive of discount)T&C
# No cost EMI ₹2,834/month. Standard EMI also availableView Plans
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# https://www.flipkart.com/search?q=realme&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3
# Realme 1 (Moonlight Silver, 32 GB)
# ₹10,999
# "No ratings for the product"
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# EMI starting from ₹518/monthView Plans
# ----------------------------------------------------------------------------------------------------
# Realme 1 (Diamond Black, 128 GB)
# ₹10,999
# 4.3
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# EMI starting from ₹518/monthView Plans
# ----------------------------------------------------------------------------------------------------
# Flipkart SmartBuy Edge To Edge Tempered Glass for Realm...
# ₹189
# 3.9
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 52% off (price inclusive of discount)T&C
# No Cost EMI on Bajaj Finserv EMI Card on cart value above ₹4499T&C
# No Cost EMI on Flipkart Axis Bank Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Flipkart SmartBuy Edge To Edge Tempered Glass for Realm...
# ₹189
# 4.2
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 52% off (price inclusive of discount)T&C
# No Cost EMI on Bajaj Finserv EMI Card on cart value above ₹4499T&C
# No Cost EMI on Flipkart Axis Bank Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# https://www.flipkart.com/search?q=realme&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4
# Krumholz Flip Cover for Realme C2
# ₹199
# 4.1
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet at flat ₹199T&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Febelo Flip Cover for Realme 5, Realme 5s
# ₹259
# 4.4
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 48% off (price inclusive of discount)T&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Flipkart SmartBuy Back Cover for Realme 5, Realme 5s
# ₹219
# 4.4
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 63% off (price inclusive of discount)T&C
# No Cost EMI on Bajaj Finserv EMI Card on cart value above ₹4499T&C
# No Cost EMI on Flipkart Axis Bank Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Spicesun Flip Cover for Realme 5, Realme 5s
# ₹229
# 4.1
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# https://www.flipkart.com/search?q=realme&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5
# Vonqo Front and Back Screen Guard for Realme 5 Pro
# ₹186
# 3.4
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# KWINE CASE Back Cover for Realme X
# ₹259
# 4.4
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 35% off (price inclusive of discount)T&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Spicesun Back Cover for Realme X
# ₹179
# 4.2
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Flipkart SmartBuy Front & Back Case for Realme 5, Realm...
# ₹299
# 4.3
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 57% off (price inclusive of discount)T&C
# No Cost EMI on Bajaj Finserv EMI Card on cart value above ₹4499T&C
# No Cost EMI on Flipkart Axis Bank Credit CardT&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# https://www.flipkart.com/search?q=realme&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6
# Aspir Back Cover for Realme 5, Realme 5s
# ₹237
# 4.3
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 20% off (price inclusive of discount)T&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# iKare Front and Back Screen Guard for OPPO A5
# ₹189
# 3.9
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 5% off (price inclusive of discount)T&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Vonqo Front and Back Screen Guard for Realme X
# ₹179
# 3.7
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet extra 5% off (price inclusive of discount)T&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------
# Febelo Flip Cover for Realme 3 Pro
# ₹229
# 4.2
# Bank Offer10% Instant Discount on ICICI Bank Credit CardsT&C
# Bank Offer5% Unlimited Cashback on Flipkart Axis Bank Credit CardT&C
# Bank OfferExtra 5% off* with Axis Bank Buzz Credit CardT&C
# Special PriceGet at flat ₹229T&C
# Partner Offer₹50 to ₹500 Scratch Card with Google Pay. Once Per User. Min order value ₹500. Only on Flipkart AppKnow More
# ----------------------------------------------------------------------------------------------------

# %%
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys

# driver = webdriver.ChromeOptions()
# driver = webdriver.Chrome("/home/sandeepa/Downloads/chromedriver", options=options)
# driver.get("http://www.google.com/")




# #open tab
# driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + 't') 
# # You can use (Keys.CONTROL + 't') on other OSs

# # driver.switch_to.new_window('tab')

# # Load a page 
# driver.get('http://stackoverflow.com/')
# # Make the tests...

# # close the tab
# # (Keys.CONTROL + 'w') on other OSs.
# driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + 'w') 


# # driver.close()

# %%
# from selenium import webdriver
# # Define the URL's we will open and a few other variables 
# main_url = 'https://www.linkedin.com' # URL A
# tab_url = 'https://www.google.com' # URL B
# chromedriver = 'DESCTINATION_TO_YOUR_CHROME_DRIVER'
# # Open main window with URL A
# browser= webdriver.Chrome(chromedriver)
# browser.get(main_url)
# print("Current Page Title is : %s" %browser.title)
# # Open a new window
# browser.execute_script("window.open('');")
# # Switch to the new window and open URL B
# browser.switch_to.window(browser.window_handles[1])
# browser.get(tab_url)
# # …Do something here
# print("Current Page Title is : %s" %browser.title)
# # Close the tab with URL B
# browser.close()
# # Switch back to the first tab with URL A
# browser.switch_to.window(browser.window_handles[0])
# print("Current Page Title is : %s" %browser.title)

# %%
# url='https://www.flipkart.com/search?q=iphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2'
# pg=requests.get(url)
# sp=BeautifulSoup(pg.text,'html.parser')
# s=sp.findAll('a',class_="_3fVaIS")
# print(s[len(s)-1].get('href'))
